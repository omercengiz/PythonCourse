# %% [markdown]
# # Exceptions
#
# * Programmer Errors
# * Program Bugs
# * Exceptions

# %%
# error example,SyntaxError.

print "Hello World!"
# Out:
#   File "<ipython-input-2-c7f6c99ffc2b>", line 3
#     print "Hello World!"
#                        ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Hello World!")?

# %%
#bug example.

num1 = input("Enter the first integer: ")
num2 = input("Enter the second integer: ")

print(num1, "+", num2, "=", num1 + num2)
# Out:
# Enter the first integer: 6
# Enter the second integer: 7
# 6 + 7 = 67

# %%
#exception example, ValueError.

num3 = int(input("First integer: "))
num4 = int(input("Second integer: "))

print(num3, "/",num4, "=", num3/num4)
# Out:
# First integer: 6
# Second integer: 7.4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-2ca720ac0e5e> in <module>
#       2
#       3 num3 = int(input("First integer: "))
# ----> 4 num4 = int(input("Second integer: "))
#       5
#       6 print(num3, "/",num4, "=", num3/num4)
#
# ValueError: invalid literal for int() with base 10: '7.4'

# %%
num4 = int(input("Second integer: "))
num4
# Out:
# Second integer: 7.4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-15b360894f7d> in <module>
# ----> 1 num4 = int(input("Second integer: "))
#       2 num4
#
# ValueError: invalid literal for int() with base 10: '7.4'

# %%
int(3.8)
# Out:
# 3

# %%
# ZeroDivisionError.


num3 = int(input("First integer: "))
num4 = int(input("Second integer: "))

print(num3, "/",num4, "=", num3/num4)
# Out:
# First integer: 7
# Second integer: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-11-c273cdf866df> in <module>
#       5 num4 = int(input("Second integer: "))
#       6
# ----> 7 print(num3, "/",num4, "=", num3/num4)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Exception Handling
#
#
# try:
#
#
# > the situations where we can get exceptions
#
# except "Exception Name":
#
#
# > the operations in case of exceptions

# %%
x = "Alan Turing"

int(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-417db27f4b47> in <module>
#       1 x = "Alan Turing"
#       2
# ----> 3 int(x)
#
# ValueError: invalid literal for int() with base 10: 'Alan Turing'

# %%
try:
  int(x)

except ValueError:
  print("Please enter an integer value!!!")
# Out:
# Please enter an integer value!!!

# %%
num3 = input("First integer: ")
num4 = input("Second integer: ")

try:
  num3_int = int(num3)
  num4_int = int(num4)

  print(num3_int, "/",num4_int, "=", num3_int/num4_int)

except ValueError:
  print("Please enter an integer value!!!")
# Out:
# First integer: 4
# Second integer: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-19-194a4a382dd0> in <module>
#       6   num4_int = int(num4)
#       7
# ----> 8   print(num3_int, "/",num4_int, "=", num3_int/num4_int)
#       9
#      10 except ValueError:
#
# ZeroDivisionError: division by zero

# %%
num3 = input("First integer: ")
num4 = input("Second integer: ")

try:
  num3_int = int(num3)
  num4_int = int(num4)

  print(num3_int, "/",num4_int, "=", num3_int/num4_int)

except ZeroDivisionError:
    print("Please enter the second input different than 0 value!!!")
    ebru = int(input("Enter a integer number"))
ebru
# Out:
# First integer: 4
# Second integer: 0
# Please enter the second input different than 0 value!!!
# Enter a integer number3
# 3

# %%
num3 = input("First integer: ")
num4 = input("Second integer: ")

try:
  num3_int = int(num3)
  num4_int = int(num4)

  print(num3_int, "/",num4_int, "=", num3_int/num4_int)

except ValueError:
  print("Please enter an integer value!!!")
except ZeroDivisionError:
  print("Please enter the second input different than 0 value!!!")
except:
  print("Unknown error...")
# Out:
# First integer: 0
# Second integer: 0
# Please enter the second input different than 0 value!!!

# %%
3.4/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-10-71f13771214b> in <module>
# ----> 1 3.4/0
#
# ZeroDivisionError: float division by zero

# %%
num3 = input("First integer: ")
num4 = input("Second integer: ")

try:
  num3_int = int(num3)
  num4_int = int(num4)

  print(num3_int, "/",num4_int, "=", num3_int/num4_int)

except (ValueError, ZeroDivisionError):
  print("Error!!!")
# Out:
# First integer: 2.5
# Second integer: 3
# Error!!!

# %%
int("3.5")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-f6c874437bf0> in <module>
# ----> 1 int("3.5")
#
# ValueError: invalid literal for int() with base 10: '3.5'

# %%
#try/except/as


num3 = input("First integer: ")
num4 = input("Second integer: ")

try:
  num3_int = int(num3)
  num4_int = int(num4)

  print(num3_int, "/",num4_int, "=", num3_int/num4_int)

except ValueError as error:
  print("Error!!!")
  print("Error message: ", error)
# Out:
# First integer: 5
# Second integer: 5.2
# Error!!!
# Error message:  invalid literal for int() with base 10: '5.2'

# %%
#exception handling in loop structure


while True:
    num1 = input("First number: (Press q for quit the program): ")

    if num1 == "q":
        break

    num2 = input("Second number: ")

    try:
        num1_int = int(num1)
        num2_int = int(num2)
        print(num1_int, "/", num2_int, "=", num1_int / num2_int)
    except (ValueError, ZeroDivisionError):
        print("Error!")
        print("Please try again!")
# Out:
# First number: (Press q for quit the program): 3
# Second number: 0
# Error!
# Please try again!
# First number: (Press q for quit the program): 3
# Second number: 3.2
# Error!
# Please try again!
# First number: (Press q for quit the program): 0
# Second number: 2
# 0 / 2 = 0.0
# First number: (Press q for quit the program): q

# %%
#try/except/as


num3 = input("First integer: ")
num4 = input("Second integer: ")

try:
  num3_int = int(num3)
  num4_int = int(num4)

  print(num3_int, "/",num4_int, "=", num3_int/num4_int)

except (ValueError, ZeroDivisionError) as error:
  print("Error!!!")
  print("Error message: ", error)
# Out:
# First integer: 5
# Second integer: 0
# Error!!!
# Error message:  division by zero

# %%
"""
exception handling in functions
using raise command
"""


def reverse(s):

    if (type(s) != str):
        raise ValueError("Please enter a String type.")
    else:
        return s[::-1]

# %%
reverse("python")
# Out:
# 'nohtyp'

# %%
reverse(12)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-9be0aeb641b6> in <module>
# ----> 1 reverse(12)
#
# <ipython-input-30-421a260d7203> in reverse(s)
#       8
#       9     if (type(s) != str):
# ---> 10         raise ValueError("Please enter a String type.")
#      11     else:
#      12         return s[::-1]
#
# ValueError: Please enter a String type.

# %% [markdown]
# # Intro to Object Oriented Programming
#
# Every entity we see around us is an object.
# Each object has its own attributes and a set of functions (methods) they perform.
#
# The concept we call class is also the data types that enable us to generate objects.

# %%
class Car():
    pass

# %%
def hello():
    pass

# %%
class Car():
    colour = "yellow"
    brand = "xyz"
    door = 4
    model = 1987

# %%
car1 = Car()

print(car1)
# Out:
# <__main__.Car object at 0x000002797141FD88>

# %%
print(car1.model)
print(car1.brand)
print(car1.door)
print(car1.colour)
# Out:
# 1987
# xyz
# 4
# yellow

# %%
car2 = Car()

car2.colour
# Out:
# 'yellow'

# %%
#We can also call attributes over the class without creating an object.

Car.model
# Out:
# 1987

# %%
Car.brand
# Out:
# 'xyz'

# %%
dir(car1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'brand',
#  'colour',
#  'door',
#  'model']

# %% [markdown]
# ### __init()__
#
# In order to create each object with different values at the beginning,
# we need to send the values of the objects.
# For this, we use a special method: __init () __
#
# The init () method is defined as a constructor function.
#
# It is the first function that is automatically called up while creating our objects.
#
# By defining this method specially, we can create our objects with different values.

# %%
class Car2():

  def __init__(self): 
    print("init function calling...")

# %% [markdown]
# self= to access any variable or other methods in the defined class.

# %%
car = Car2()
# Out:
# init function calling...

# %%
class Car3():

  def __init__(self, colour, brand, door):
    self.colour = colour
    self.brand = brand
    self.door = door


red_car = Car3("red", "abc",2)

yellow_car = Car3("yellow", "xyz", 4)

print(red_car.colour)
print(yellow_car.brand)
# Out:
# red
# xyz

# %%
blue_car = Car3()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-2993678ac391> in <module>
# ----> 1 blue_car = Car3()
#
# TypeError: __init__() missing 3 required positional arguments: 'colour', 'brand', and 'door'

# %%
blue_car = Car3("blue","xyz")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-6b3d9a135cf0> in <module>
# ----> 1 blue_car = Car3("blue","xyz")
#
# TypeError: __init__() missing 1 required positional argument: 'door'

# %%
blue_car = Car3("blue","bnm",10)

print(blue_car.brand)
print(blue_car.colour)
print(blue_car.door)
# Out:
# bnm
# blue
# 10

# %%
class Person():
  name = ""
  age = 0

  def __init__(self, personName, personAge):
    self.name = personName
    self.age = personAge


  def welcomePerson(self):
    print("Hello " + self.name)

  
  def showAge(self):
    print(self.age)

# %%
person1 = Person ("Asli", 28)

person1.welcomePerson()
# Out:
# Hello Asli

# %%
person1.showAge()
# Out:
# 28

# %% [markdown]
# # Question

# %%
class Person3():
    def __init__(self, name, age):
        self.name = name
        self.age = age
        self.language = []
        
    def welcomePerson(self):
        print("Hello",self.name)
    
    def showAge(self):
        print(self.age)
        
    def addLanguage(self,new_lang):
        print("Adding new language")
        self.language.append(new_lang)
    def showInfo(self):
        print("{} is {} years old".format(self.name,self.age))
        print("He can speak:")
        for i in self.language:
              print(i)

# %%
Ferhat = Person3("Ferhat",21)

# %%
Ferhat

# %%
Ferhat.addLanguage("Spanish")
# Out:
# Adding new language

# %%
Ferhat.showAge()
# Out:
# 21

# %%
Ferhat.showInfo()
# Out:
# Ferhat is 21 years old
# He can speak:
# Spanish

# %%
Ferhat.welcomePerson()
# Out:
# Hello Ferhat

# %%
Ferhat.addLanguage("Spanish")
# Out:
# Adding new language

# %%
Ferhat.showInfo()
# Out:
# Ferhat is 21 years old
# He can speak:
# Spanish
# Spanish

# %%
Ferhat.addLanguage("English")
# Out:
# Adding new language

# %%
Ferhat.showInfo()
# Out:
# Ferhat is 21 years old
# He can speak:
# Spanish
# Spanish
# English
